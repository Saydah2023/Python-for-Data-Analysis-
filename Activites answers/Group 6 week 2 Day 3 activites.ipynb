# %%
#1.Write a Python program to test if a given page is found or not on the server.

from bs4 import BeautifulSoup
import requests

html = urlopen('https://www.google.ca/')

url_obj = BeautifulSoup(html,"html5lib")
if url_obj.find("title"):
   print("Page found sucessfully on server")
else:
   print("Page not found")
# Out:
# Page found sucessfully on server

# %%
#2.Write a Python program to extract and display all the header tags from en.wikipedia.org/wiki/Main_Page
from urllib.request import urlopen
html = urlopen('https://en.wikipedia.org/wiki/Main_Page')
header_obj = BeautifulSoup(html,"html5lib")
title = header_obj.find_all(['h1','h2','h3','h4','h5','h6'])
print("list all the header tags:",*title,sep='\n\n')
# Out:
# list all the header tags:
#
# <h1 class="firstHeading mw-first-heading" id="firstHeading" style="display: none"><span class="mw-page-title-main">Main Page</span></h1>
#
# <h1><span class="mw-headline" id="Welcome_to_Wikipedia">Welcome to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a></span></h1>
#
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
#
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
#
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
#
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
#
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
#
# <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>
#
# <h2 class="mp-h2" id="mp-sister"><span id="Wikipedia.27s_sister_projects"></span><span class="mw-headline" id="Wikipedia's_sister_projects">Wikipedia's sister projects</span></h2>
#
# <h2 class="mp-h2" id="mp-lang"><span class="mw-headline" id="Wikipedia_languages">Wikipedia languages</span></h2>

# %%
#3.	Write a Python program to get 90 days of visits broken down by browser for all sites on data.gov.
data = requests.get("https://analytics.usa.gov/data/live/browsers.json")
print("90 days of visits broken down by browser for all sites:")
print(data.json()['totals']['browser'])
# Out:
# 90 days of visits broken down by browser for all sites:
# {'Chrome': 2699371315, 'Safari': 1998830956, 'Edge': 474385430, 'Firefox': 126069273, 'Safari (in-app)': 101756434, 'Samsung Internet': 86256561, 'Android Webview': 52307077, 'Internet Explorer': 17461035, 'Opera': 16496799, 'Amazon Silk': 7808516, '(not set)': 5533807, 'Mozilla Compatible Agent': 2650770, 'YaBrowser': 2015605, 'UC Browser': 819463, 'Whale Browser': 571068, 'Coc Coc': 262102, 'Opera Mini': 326998, 'Android Browser': 54411, 'Maxthon': 3249, 'Aloha Browser': 115025, 'Lynx': 199905, 'Mozilla': 51495, 'DuckDuckGo Browser': 44251, 'Android Runtime': 95281, 'SeaMonkey': 44086, 'PaleMoon': 48340, 'Phoenix Browser': 44147, 'Iron': 34944, 'Vivaldi': 26502, 'Waterfox': 13409, 'Meta Quest Browser': 26205, 'Seznam': 5937, 'Puffin': 6528, '(other)': 356205, 'BlackBerry': 1203, 'Konqueror': 903, 'NetFront': 919}

# %%
#4.	Write a Python program to extract and display all the image links from en.wikipedia.org/wiki/Peter_Jeffrey_(RAAF_officer)
import re
url = "https://en.wikipedia.org/wiki/Peter_Jeffrey_(RAAF_officer)"
data = requests.get(url).text
img_obj = BeautifulSoup(data,"html5lib")
for link in img_obj.find_all('img', {'src':re.compile('.jpg')}):
    print(link['src']+'\n')
# Out:
# //upload.wikimedia.org/wikipedia/commons/thumb/a/af/NlaJeffrey1942-43.jpg/220px-NlaJeffrey1942-43.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/c/c5/008315JeffreyTurnbull1941.jpg/260px-008315JeffreyTurnbull1941.jpg
#
# //upload.wikimedia.org/wikipedia/commons/e/ea/021807CameronJeffrey1941.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/9/92/AC0072JeffreyTruscottKittyhawks1942.jpg/280px-AC0072JeffreyTruscottKittyhawks1942.jpg
#
# //upload.wikimedia.org/wikipedia/commons/thumb/2/26/VIC1689Jeffrey1945.jpg/280px-VIC1689Jeffrey1945.jpg

# %%
#5.	Write a Python program to get the number of people visiting a U.S. government website right now. Source: https://analytics.usa.gov/data/live/realtime.json
url = ' https://analytics.usa.gov/data/live/realtime.json'
us_obj = requests.get(url).json()
print("Number of people visiting a U.S. government website right now  is :")
print(us_obj['data'][0]['active_visitors'])
# Out:
# Number of people visiting a U.S. government website right now  is :
# 21355

# %%
#6.	Write a Python program to get the number of followers of a given twitter account. Choose any twitter account of your favorite celebrity

# %%
#7.	Write a Python program to get the number of followers of a given twitter account.

# %%
#8.	Write a Python program to display the contains of different attributes like different attributes like status_code, headers, url, history, encoding, reason, cookies, elapsed, request and content of a specified resource.
response = requests.get('https://npowercanada.ca/')

print("Status Code: ",response.status_code)
print("Headers: ",response.headers)
print("Url: ",response.url)
print("History: ",response.history)
print("Encoding: ",response.encoding)
print("Reason: ",response.reason)
print("Cookies: ",response.cookies)
print("Elapsed: ",response.elapsed)
print("Request: ",response.request)
print("Content: ",response._content)
# Out:
# Status Code:  403
# Headers:  {'Date': 'Wed, 28 Feb 2024 02:55:45 GMT', 'Content-Type': 'text/html; charset=utf8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'x-frame-options': 'sameorigin', 'x-content-type-options': 'nosniff', 'x-xss-protection': '1; mode=block', 'pre-cognitive-push': 'Enabled', 'quantum-flux-capacity': 'Omega', 'strict-transport-security': 'max-age=31536000', 'Cache-Control': 'public, no-cache', 'referrer-policy': 'strict-origin-when-cross-origin', 'CF-Cache-Status': 'DYNAMIC', 'Report-To': '{"endpoints":[{"url":"https:\\/\\/a.nel.cloudflare.com\\/report\\/v3?s=YRZHESyOsWbXPnLyPUAAZox1FWKS4l24UimnFitO7Yq8u6fWESSWtmrpxDAZw9EesXcr%2F3hOgpSvwxDj8xFL9lIzDUo%2FW5MIDdWeLbMdHEsKXxz0XFiJVQirF1U13RHQT0loZ%2FxL9KGVBsOZyo4%3D"}],"group":"cf-nel","max_age":604800}', 'NEL': '{"success_fraction":0,"report_to":"cf-nel","max_age":604800}', 'Server': 'cloudflare', 'CF-RAY': '85c563f709c5810b-ORD', 'Content-Encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400'}
# Url:  https://npowercanada.ca/
# History:  []
# Encoding:  utf8
# Reason:  Forbidden
# Cookies:  <RequestsCookieJar[]>
# Elapsed:  0:00:00.813557
# Request:  <PreparedRequest [GET]>
# Content:  b'<html>\r\n<head><title>403 Forbidden</title></head>\r\n<body>\r\n<center><h1>403 Forbidden</h1></center>\r\n<hr><center>nginx</center>\r\n</body>\r\n</html>\r\n'

# %%
#9.	Write a Python program to extract h1 tag from example.com.

html = urlopen('http://www.example.com/')
tag = BeautifulSoup(html.read(), 'html.parser')
print(tag.h1)
# Out:
# <h1>Example Domain</h1>

# %%
#10.	Write a Python program to get the number of datasets currently listed on data.gov.
gov_class = 'hero__dataset-count'
response = get_page('https://data.gov/')

gov_obj = BeautifulSoup(response.content, 'html.parser')

element = gov_obj.find(class_= gov_class)

print(int(element.text.split('datasets available')[0].replace('\n', '').replace(' ', '').replace(',', '')))
# Out:
# 292374
